# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("starwars.csv")

# %% [markdown]
# Analysing: Which of the following Star Wars films have you seen?

# %%
from random import sample
df.iloc[sample(df.index,10),3:9]
# Out:
#      Which of the following Star Wars films have you seen? Please select all that apply.  \
# 993                                                 NaN
# 908                                                 NaN
# 775            Star Wars: Episode I  The Phantom Menace
# 225            Star Wars: Episode I  The Phantom Menace
# 716                                                 NaN
# 1049                                                NaN
# 127                                                 NaN
# 450                                                 NaN
# 288                                                 NaN
# 951            Star Wars: Episode I  The Phantom Menace
#
#                                        Unnamed: 4  \
# 993                                           NaN
# 908   Star Wars: Episode II  Attack of the Clones
# 775                                           NaN
# 225   Star Wars: Episode II  Attack of the Clones
# 716                                           NaN
# ...

# %%
df.iloc[sample(df.index,20),40:46]
# Out:
#       Star Wars: Episode I  The Phantom Menace  \
# 757                                        NaN
# 66                                         NaN
# 59                                         NaN
# 947                                        NaN
# 605                                        NaN
# 660                                        NaN
# 793                                        NaN
# 1056                                       NaN
# 353                                        NaN
# 1005                                       NaN
# 573                                        NaN
# 355                                        NaN
# 317                                        NaN
# 998                                        NaN
# 439                                        NaN
# 95                                         NaN
# 777                                        NaN
# 167                                        NaN
# 292                                        NaN
# ...

# %% [markdown]
# Renaming columns for identification purposes

# %%
df2 = df.rename(columns= {'Which of the following Star Wars films have you seen? Please select all that apply.'
                          : 'Star Wars: Episode I The Phantom Menace',
                          'Unnamed: 4' : 'Episode II Attack of the Clones',
                          'Unnamed: 5' : 'Episode III Revenge of the Sith',
                          'Unnamed: 6' : 'Episode IV A New Hope',
                          'Unnamed: 7' : 'Star Wars: Episode V The Empire Strikes Back',
                          'Unnamed: 8' : 'Star Wars: Episode VI Return of the Jedi'})

# %%
df2 = df2.iloc[0:,3:9]

# %%
df2.describe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-196-33497a1b1a6c> in <module>()
# ----> 1 sorted(df2).describe()
#
# AttributeError: 'list' object has no attribute 'describe'

# %% [markdown]
# Let's do some plotting

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
x = [1, 2, 3, 4, 5, 6]
y = [673, 571, 550, 607, 758, 738]
xticks = ['Ep. I',
          'Ep. II',
          'Ep. III',
          'Ep. IV',
         'Ep. V',
         'Ep. VI']
plt.bar(x, y, align='center')
plt.xticks(x, xticks)
plt.show()

# %%
plt.plot(x,y)
