# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("starwars.csv")

# %%
from random import sample
df.iloc[sample(df.index,5),9:15]
# Out:
#      Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  \
# 565                                                  4
# 919                                                  1
# 581                                                  4
# 441                                                  4
# 139                                                  3
#
#      Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# 565            5            6            1            2            3
# 919            3            5            6            2            4
# 581            1            5            6            3            2
# 441            5            6            2            1            3
# 139            6            4            5            1            2

# %%
df.iloc[sample(df.index,20),46:52]
# Out:
#       Star Wars: Episode I  The Phantom Menace.1  \
# 87                                           NaN
# 732                                          NaN
# 708                                          NaN
# 342                                          NaN
# 460                                          NaN
# 819                                          NaN
# 384                                          NaN
# 520                                          NaN
# 591                                          NaN
# 739                                          NaN
# 209                                          NaN
# 110                                          NaN
# 590                                          NaN
# 1129                                         NaN
# 662                                          NaN
# 693                                          NaN
# 138                                          NaN
# 841                                          NaN
# ...

# %%
df2 = df.rename(columns= {'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.'
                          : 'Episode I The Phantom Menace',
                          'Unnamed: 10' : 'Episode II Attack of the Clones',
                          'Unnamed: 11' : 'Episode III Revenge of the Sith',
                          'Unnamed: 12' : 'Episode IV A New Hope',
                          'Unnamed: 13' : 'Episode V The Empire Strikes Back',
                          'Unnamed: 14' : 'Episode VI Return of the Jedi'})

# %%
df2 = df2.iloc[0:,9:15]

# %%
df2.iloc[sample(df.index,10),0:]
# Out:
#       Episode I The Phantom Menace  Episode II Attack of the Clones  \
# 1052                           NaN                              NaN
# 150                            NaN                              NaN
# 1163                             5                                6
# 1066                             5                                4
# 518                              6                                4
# 136                            NaN                              NaN
# 881                            NaN                              NaN
# 630                              4                                5
# 1061                           NaN                              NaN
# 363                            NaN                              NaN
#
#       Episode III Revenge of the Sith  Episode IV A New Hope  \
# 1052                              NaN                    NaN
# 150                               NaN                    NaN
# ...

# %%
df2.describe()
# Out:
#        Episode I The Phantom Menace  Episode II Attack of the Clones  \
# count                    835.000000                       836.000000
# mean                       3.732934                         4.087321
# std                        1.656122                         1.365365
# min                        1.000000                         1.000000
# 25%                        3.000000                         3.000000
# 50%                        4.000000                         4.000000
# 75%                        5.000000                         5.000000
# max                        6.000000                         6.000000
#
#        Episode III Revenge of the Sith  Episode IV A New Hope  \
# count                       835.000000             836.000000
# mean                          4.341317               3.272727
# std                           1.400464               1.825901
# min                           1.000000               1.000000
# ...

# %%
df2.mean()
# Out:
# Episode I The Phantom Menace         3.732934
# Episode II Attack of the Clones      4.087321
# Episode III Revenge of the Sith      4.341317
# Episode IV A New Hope                3.272727
# Episode V The Empire Strikes Back    2.513158
# Episode VI Return of the Jedi        3.047847
# dtype: float64

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib as mpl

# %%
x = [1, 2, 3, 4, 5, 6]
y = [3.732934, 4.087321, 4.341317, 3.272727, 2.513158, 3.047847]
xticks = ['Ep. I',
          'Ep. II',
          'Ep. III',
          'Ep. IV',
         'Ep. V',
         'Ep. VI']
plt.bar(x, y, align='center')
plt.xticks(x, xticks)
plt.show()
