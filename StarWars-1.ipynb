# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("starwars.csv")

# %%
df.describe()
# Out:
#        RespondentID  \
# count  1.186000e+03
# mean   3.290128e+09
# std    1.055639e+06
# min    3.288373e+09
# 25%    3.289451e+09
# 50%    3.290147e+09
# 75%    3.290814e+09
# max    3.292880e+09
#
#        Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.  \
# count                                         835.000000
# mean                                            3.732934
# std                                             1.656122
# min                                             1.000000
# 25%                                             3.000000
# 50%                                             4.000000
# 75%                                             5.000000
# max                                             6.000000
#
#        Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14  \
# count   836.000000   835.000000   836.000000   836.000000   836.000000
# ...

# %%
df.columns.values
# Out:
# array(['RespondentID',
#        'Have you seen any of the 6 films in the Star Wars franchise?',
#        'Do you consider yourself to be a fan of the Star Wars film franchise?',
#        'Which of the following Star Wars films have you seen? Please select all that apply.',
#        'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8',
#        'Please rank the Star Wars films in order of preference with 1 being your favorite film in the franchise and 6 being your least favorite film.',
#        'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13',
#        'Unnamed: 14',
#        'Please state whether you view the following characters favorably, unfavorably, or are unfamiliar with him/her.',
#        'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19',
#        'Unnamed: 20', 'Unnamed: 21', 'Unnamed: 22', 'Unnamed: 23',
#        'Unnamed: 24', 'Unnamed: 25', 'Unnamed: 26', 'Unnamed: 27',
#        'Unnamed: 28', 'Which character shot first?',
# ...

# %%
from random import sample
df.iloc[sample(df.index,15),37:50]
# Out:
#      Location (Census Region)  Response  Response.1  \
# 957           Middle Atlantic       NaN         NaN
# 636                   Pacific       NaN         NaN
# 496                       NaN       NaN         NaN
# 717        East North Central       NaN         NaN
# 220        East North Central       NaN         NaN
# 66             South Atlantic       NaN         NaN
# 665                   Pacific       NaN         NaN
# 386        West North Central       NaN         NaN
# 1082                      NaN       NaN         NaN
# 372                       NaN       NaN         NaN
# 212           Middle Atlantic       NaN         NaN
# 60                    Pacific       NaN         NaN
# 812                  Mountain       NaN         NaN
# 434        East North Central       NaN         NaN
# 132            South Atlantic       NaN         NaN
#
#       Star Wars: Episode I  The Phantom Menace  \
# 957                                        NaN
# ...

# %% [markdown]
# Missing data from columns 38 to 75 --> drop all those columns

# %%
df = df.drop(df.iloc[:,38:],1)
df.iloc[sample(df.index,15),37:50]
# Out:
#      Location (Census Region)
# 944               New England
# 1106          Middle Atlantic
# 265        East North Central
# 534                   Pacific
# 362            South Atlantic
# 1014       West South Central
# 1051                 Mountain
# 1104       East South Central
# 49                    Pacific
# 378        West South Central
# 613        East North Central
# 540            South Atlantic
# 335        East North Central
# 373                  Mountain
# 394           Middle Atlantic

# %% [markdown]
# Issue when calling column 'Do you consider yourself to be a fan of the Expanded Universe?' (index 31) --> drop it

# %%
df = df.drop(df.iloc[:,31:32],1)
df.iloc[sample(df.index,10),30:32]
# Out:
#      Are you familiar with the Expanded Universe?  \
# 1095                                          NaN
# 911                                            No
# 96                                            NaN
# 299                                            No
# 340                                            No
# 166                                           Yes
# 558                                           NaN
# 859                                            No
# 34                                            NaN
# 442                                           Yes
#
#      Do you consider yourself to be a fan of the Star Trek franchise?
# 1095                                                 No
# 911                                                  No
# 96                                                  NaN
# 299                                                  No
# 340                                                 Yes
# 166                                                  No
# ...

# %%
df.ix[sample(df.index,10),['Household Income','Have you seen any of the 6 films in the Star Wars franchise?']]
# Out:
#        Household Income  \
# 110   $50,000 - $99,999
# 1121                NaN
# 301                 NaN
# 686   $50,000 - $99,999
# 1104  $50,000 - $99,999
# 556   $50,000 - $99,999
# 647                 NaN
# 611                 NaN
# 295        $0 - $24,999
# 662   $50,000 - $99,999
#
#      Have you seen any of the 6 films in the Star Wars franchise?
# 110                                                 Yes
# 1121                                                Yes
# 301                                                 Yes
# 686                                                 Yes
# 1104                                                Yes
# 556                                                 Yes
# 647                                                  No
# 611                                                 Yes
# 295                                                 Yes
# 662                                                 Yes

# %%
df['RespondentID'].head()
# Out:
# 0    3292879998
# 1    3292879538
# 2    3292765271
# 3    3292763116
# 4    3292731220
# Name: RespondentID, dtype: int64

# %%
df['Have you seen any of the 6 films in the Star Wars franchise?'].tail()
# Out:
# 1181    Yes
# 1182    Yes
# 1183     No
# 1184    Yes
# 1185    Yes
# Name: Have you seen any of the 6 films in the Star Wars franchise?, dtype: object

# %%
df['Do you consider yourself to be a fan of the Star Wars film franchise?'][0:10]
# Out:
# 0    Yes
# 1    NaN
# 2     No
# 3    Yes
# 4    Yes
# 5    Yes
# 6    Yes
# 7    Yes
# 8    Yes
# 9     No
# Name: Do you consider yourself to be a fan of the Star Wars film franchise?, dtype: object

# %%
df['Which character shot first?'][100:150]
# Out:
# 100    I don't understand this question
# 101                              Greedo
# 102                              Greedo
# 103                                 NaN
# 104                                 NaN
# 105                                 NaN
# 106                              Greedo
# 107                                 Han
# 108    I don't understand this question
# 109    I don't understand this question
# 110                                 Han
# 111                              Greedo
# 112    I don't understand this question
# 113                                 Han
# 114    I don't understand this question
# 115                                 NaN
# 116    I don't understand this question
# 117                                 Han
# 118                                 NaN
# 119                                 NaN
# 120    I don't understand this question
# 121                                 NaN
# 122                                 Han
# ...

# %%
df['Are you familiar with the Expanded Universe?'][180:200]
# Out:
# 180    NaN
# 181     No
# 182    NaN
# 183     No
# 184    NaN
# 185    Yes
# 186     No
# 187    Yes
# 188     No
# 189    NaN
# 190    NaN
# 191     No
# 192    NaN
# 193    NaN
# 194     No
# 195    NaN
# 196    Yes
# 197    NaN
# 198     No
# 199    NaN
# Name: Are you familiar with the Expanded Universe?, dtype: object

# %%
df['Do you consider yourself to be a fan of the Star Trek franchise?'][0:3]
# Out:
# 0     No
# 1    Yes
# 2     No
# Name: Do you consider yourself to be a fan of the Star Trek franchise?, dtype: object

# %%
df['Gender'].tail()
# Out:
# 1181    Female
# 1182    Female
# 1183    Female
# 1184    Female
# 1185    Female
# Name: Gender, dtype: object

# %%
df['Age'][980:1000]
# Out:
# 980    45-60
# 981    30-44
# 982     > 60
# 983     > 60
# 984    18-29
# 985     > 60
# 986    18-29
# 987     > 60
# 988    18-29
# 989    18-29
# 990    30-44
# 991    45-60
# 992    18-29
# 993      NaN
# 994    30-44
# 995    18-29
# 996    18-29
# 997    18-29
# 998    18-29
# 999    18-29
# Name: Age, dtype: object

# %%
df['Household Income'][1150:]
# Out:
# 1150                    NaN
# 1151      $50,000 - $99,999
# 1152           $0 - $24,999
# 1153      $50,000 - $99,999
# 1154      $50,000 - $99,999
# 1155    $100,000 - $149,999
# 1156      $50,000 - $99,999
# 1157    $100,000 - $149,999
# 1158           $0 - $24,999
# 1159           $0 - $24,999
# 1160      $25,000 - $49,999
# 1161                    NaN
# 1162      $25,000 - $49,999
# 1163                    NaN
# 1164    $100,000 - $149,999
# 1165      $50,000 - $99,999
# 1166              $150,000+
# 1167                    NaN
# 1168              $150,000+
# 1169      $25,000 - $49,999
# 1170                    NaN
# 1171      $25,000 - $49,999
# 1172                    NaN
# 1173                    NaN
# 1174                    NaN
# 1175      $50,000 - $99,999
# 1176           $0 - $24,999
# 1177      $50,000 - $99,999
# 1178                    NaN
# 1179           $0 - $24,999
# 1180           $0 - $24,999
# 1181           $0 - $24,999
# 1182      $50,000 - $99,999
# ...

# %%
df['Education'].tail()
# Out:
# 1181    Some college or Associate degree
# 1182                     Bachelor degree
# 1183                     Bachelor degree
# 1184    Some college or Associate degree
# 1185                     Graduate degree
# Name: Education, dtype: object

# %%
df['Location (Census Region)'].head()
# Out:
# 0        South Atlantic
# 1    West South Central
# 2    West North Central
# 3    West North Central
# 4    West North Central
# Name: Location (Census Region), dtype: object
